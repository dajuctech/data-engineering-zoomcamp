# %% [markdown]
# #### Setup — Import PySpark and Start SparkSession

# %%
import pyspark

# %%
from pyspark.sql import SparkSession

# %%
pyspark.__version__
# Out:
# '4.1.1'

# %%
 pyspark.__file__
# Out:
# '/workspaces/data-engineering-zoomcamp/06-batch/.venv/lib/python3.13/site-packages/pyspark/__init__.py'

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .master("local[*]") \
    .appName("spark_basics") \
    .getOrCreate()

print("Spark version:", spark.version)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/02/25 18:15:34 WARN Utils: Your hostname, codespaces-91f0b4, resolves to a loopback address: 127.0.0.1; using 10.0.0.114 instead (on interface eth0)
# 26/02/25 18:15:34 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/25 18:15:35 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Spark version: 4.1.1

# %% [markdown]
# #### Download Data — Taxi Zone Lookup CSV

# %%
# !wget https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/taxi_zone_lookup.csv
# Out:
# --2026-02-25 18:15:43--  https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/taxi_zone_lookup.csv
# Resolving github.com (github.com)... 20.26.156.215
# Connecting to github.com (github.com)|20.26.156.215|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/513814948/5a2cc2f5-b4cd-4584-9c62-a6ea97ed0e6a?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-02-25T18%3A58%3A32Z&rscd=attachment%3B+filename%3Dtaxi_zone_lookup.csv&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-02-25T17%3A58%3A00Z&ske=2026-02-25T18%3A58%3A32Z&sks=b&skv=2018-11-09&sig=iVksPzY9nkLOuPgUzHByV%2FNlm1CZFFBz8%2BILqXVvZHI%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3MjA0MzY0MywibmJmIjoxNzcyMDQzMzQzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.W8QEdWHiOSCfqqGOpaBFmSMXykxrgcgvSBURtdbtq1U&response-content-disposition=attachment%3B%20filename%3Dtaxi_zone_lookup.csv&response-content-type=application%2Foctet-stream [following]
# --2026-02-25 18:15:43--  https://release-assets.githubusercontent.com/github-production-release-asset/513814948/5a2cc2f5-b4cd-4584-9c62-a6ea97ed0e6a?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-02-25T18%3A58%3A32Z&rscd=attachment%3B+filename%3Dtaxi_zone_lookup.csv&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-02-25T17%3A58%3A00Z&ske=2026-02-25T18%3A58%3A32Z&sks=b&skv=2018-11-09&sig=iVksPzY9nkLOuPgUzHByV%2FNlm1CZFFBz8%2BILqXVvZHI%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3MjA0MzY0MywibmJmIjoxNzcyMDQzMzQzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.W8QEdWHiOSCfqqGOpaBFmSMXykxrgcgvSBURtdbtq1U&response-content-disposition=attachment%3B%20filename%3Dtaxi_zone_lookup.csv&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12322 (12K) [application/octet-stream]
# Saving to: ‘taxi_zone_lookup.csv.4’
#
# taxi_zone_lookup.cs 100%[===================>]  12.03K  --.-KB/s    in 0s
#
# 2026-02-25 18:15:43 (26.1 MB/s) - ‘taxi_zone_lookup.csv.4’ saved [12322/12322]

# %% [markdown]
# #### Read CSV File into Spark DataFrame

# %%
df = spark.read \
    .option("header", "true") \
    .csv("taxi_zone_lookup.csv")

# %% [markdown]
# #### Show Data — Preview the DataFrame

# %%
df.show()
# Out:
# +----------+-------------+--------------------+------------+
# |LocationID|      Borough|                Zone|service_zone|
# +----------+-------------+--------------------+------------+
# |         1|          EWR|      Newark Airport|         EWR|
# |         2|       Queens|         Jamaica Bay|   Boro Zone|
# |         3|        Bronx|Allerton/Pelham G...|   Boro Zone|
# |         4|    Manhattan|       Alphabet City| Yellow Zone|
# |         5|Staten Island|       Arden Heights|   Boro Zone|
# |         6|Staten Island|Arrochar/Fort Wad...|   Boro Zone|
# |         7|       Queens|             Astoria|   Boro Zone|
# |         8|       Queens|        Astoria Park|   Boro Zone|
# |         9|       Queens|          Auburndale|   Boro Zone|
# |        10|       Queens|        Baisley Park|   Boro Zone|
# |        11|     Brooklyn|          Bath Beach|   Boro Zone|
# |        12|    Manhattan|        Battery Park| Yellow Zone|
# |        13|    Manhattan|   Battery Park City| Yellow Zone|
# |        14|     Brooklyn|           Bay Ridge|   Boro Zone|
# |        15|       Queens|Bay Terrace/Fort ...|   Boro Zone|
# |        16|       Queens|             Bayside|   Boro Zone|
# |        17|     Brooklyn|             Bedford|   Boro Zone|
# |        18|        Bronx|        Bedford Park|   Boro Zone|
# |        19|       Queens|           Bellerose|   Boro Zone|
# |        20|        Bronx|             Belmont|   Boro Zone|
# +----------+-------------+--------------------+------------+
# only showing top 20 rows

# %% [markdown]
# #### Save to Parquet Format

# %%
#df.write.parquet("zones
df.write.mode("overwrite").parquet("zones")

# %% [markdown]
# #### Verify Output Files

# %%
# !ls -lh
# Out:
# total 416K
# -rw-rw-rw-  1 codespace codespace    0 Feb 25 16:52 README.md
# -rw-rw-rw-  1 codespace codespace   86 Feb 25 16:52 main.py
# -rw-rw-rw-  1 codespace codespace  223 Feb 25 17:05 pyproject.toml
# -rw-rw-rw-  1 codespace codespace  16K Feb 25 18:17 spark_basics.ipynb
# -rw-rw-rw-  1 codespace codespace  13K Jul 19  2022 taxi_zone_lookup.csv
# -rw-rw-rw-  1 codespace codespace  13K Jul 19  2022 taxi_zone_lookup.csv.1
# -rw-rw-rw-  1 codespace codespace  13K Jul 19  2022 taxi_zone_lookup.csv.2
# -rw-rw-rw-  1 codespace codespace  13K Jul 19  2022 taxi_zone_lookup.csv.3
# -rw-rw-rw-  1 codespace codespace  13K Jul 19  2022 taxi_zone_lookup.csv.4
# -rw-rw-rw-  1 codespace codespace  330 Feb 25 16:55 test_spark.py
# -rw-rw-rw-  1 codespace codespace 135K Feb 25 17:38 tlc-trip-record-data.page
# -rw-rw-rw-  1 codespace codespace 167K Feb 25 17:05 uv.lock
# drwxr-xr-x+ 2 codespace codespace 4.0K Feb 25 18:18 zones
